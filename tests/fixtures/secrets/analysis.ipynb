# %% [markdown]
# # Data Analysis Notebook
# This notebook connects to the database and runs analysis.

# %%
import os
import openai

# WARNING: Do not commit credentials!
OPENAI_API_KEY = 'sk-abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRS'
DB_PASSWORD = 'super_secret_password_123'
AWS_KEY = 'AKIAIOSFODNN7EXAMPLE'

openai.api_key = OPENAI_API_KEY

# %%
conn_str = f'postgresql://admin:{DB_PASSWORD}@prod.db.example.com:5432/mydb'
print('Connected to database')
print(f'Using key: {AWS_KEY}')
# Out:
# Connected to database
# Using key: AKIAIOSFODNN7EXAMPLE
